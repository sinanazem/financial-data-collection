# %% [markdown]
# - https://rapidapi.com/apidojo/api/seeking-alpha/

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/v2/auto-complete"

querystring = {"query":"apple","type":"people,symbols,pages","size":"5"}

headers = {
"X-RapidAPI-Key": "",
"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"people":[{"name":"Apple Investor","slug":"apple-investor","id":11533,"content":null},{"name":"Apple Grade Stocks","slug":"apple-grade-stocks","id":49961,"content":null},{"name":"Little Apple","slug":"little-apple","id":35478,"content":null},{"name":"Michelle Galanter Applebaum","slug":"michelle-galanter-applebaum","id":15026,"content":null},{"name":"appledoc","slug":null,"id":48397819,"content":null}],"symbols":[{"id":146,"name":"AAPL","slug":"aapl","content":"Apple Inc.","exchange":"NASDAQ","currency":"USD","is_quant_rated":1},{"id":513836,"name":"APLE","slug":"aple","content":"Apple Hospitality REIT, Inc.","exchange":"NYSE","currency":"USD","is_quant_rated":1},{"id":279515,"name":"APPLX","slug":"applx","content":"Appleseed Fund Inv","exchange":"MUTF","currency":"USD","is_quant_rated":0},{"id":20465,"name":"APRU","slug":"apru","content":"Apple Rush Company, Inc.","exchange":"OTCMKTS","currency":"USD","is_quant_rated":0},{"id":24895,"name":"GAPJ","slug":"gapj","content":"Golden Apple Oil & Gas Inc.","exchange":"OTCMKTS","currency":"USD","is_quant_rated":0}],"pages":[]}

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"aapl","size":"20","number":"1"}

headers = {
"X-RapidAPI-Key": "",
"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"id":"4550156","type":"transcript","attributes":{"publishOn":"2022-10-27T19:46:03-04:00","isLockedPro":false,"commentCount":1,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) Q4 2022 Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4550156-apple-inc-aapl-q4-2022-earnings-call-transcript"}},{"id":"4527231","type":"transcript","attributes":{"publishOn":"2022-07-28T21:11:05-04:00","isLockedPro":false,"commentCount":4,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple, Inc. (AAPL) CEO Tim Cook on Q3 2022 Results - Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4527231-apple-inc-aapl-ceo-tim-cook-on-q3-2022-results-earnings-call-transcript"}},{"id":"4504834","type":"transcript","attributes":{"publishOn":"2022-04-28T19:21:03-04:00","isLockedPro":false,"commentCount":2,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q2 2022 Results - Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4504834-apple-inc-aapl-ceo-tim-cook-on-q2-2022-results-earnings-call-transcript"}},{"id":"4482308","type":"transcript","attributes":{"publishOn":"2022-01-27T20:19:05-05:00","isLockedPro":false,"commentCount":1,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q1 2022 Results - Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4482308-apple-inc-aapl-ceo-tim-cook-on-q1-2022-results-earnings-call-transcript"}},{"id":"4463261","type":"transcript","attributes":{"publishOn":"2021-10-28T21:25:05-04:00","isLockedPro":false,"commentCount":7,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q4 2021 Results - Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4463261-apple-inc-aapl-ceo-tim-cook-on-q4-2021-results-earnings-call-transcript"}},{"id":"4441901","type":"transcript","attributes":{"publishOn":"2021-07-27T23:13:05-04:00","isLockedPro":false,"commentCount":8,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q3 2021 Results - Earnings Call Transcript","isPaywalled":false},"relationships":{"author":{"data":{"id":"44211","type":"author"}},"sentiments":{"data":[]},"primaryTickers":{"data":[{"id":"146","type":"tag"}]},"secondaryTickers":{"data":[]},"otherTags":{"data":[{"id":"49","type":"tag"}]}},"links":{"self":"/article/4441901-apple-inc-aapl-ceo-tim-cook-on-q3-2021-results-earnings-call-transcript"}},{"id":"4422230","type":"transcript","attributes":{"publishOn":"2021-04-28T21:17:11-04:00","isLockedPro":false,"commentCount":8,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q2 2021 Results - Earnings Call Transcript","isPaywalled":false} ...

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

querystring = {"id":"4341792"}

headers = {
"X-RapidAPI-Key": "",
"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":{"id":"4341792","type":"fullArticle","attributes":{"publishOn":"2020-04-30T21:51:10-04:00","isLockedPro":false,"commentCount":19,"gettyImageUrl":null,"videoPreviewUrl":null,"themes":{"sa-transcripts":{"slug":"sa-transcripts","kind":"common","non_theme":true},"aapl":{"slug":"aapl","kind":"common","non_theme":true},"technology":{"slug":"technology","kind":"sector","path":"/earnings/earnings-call-transcripts?sector=technology","title":"Technology"},"transcripts":{"slug":"transcripts","kind":"general","path":"/earnings/earnings-call-transcripts","title":"Transcripts"},"has-audio":{"slug":"has-audio","kind":"general"},"us":{"slug":"us","kind":"common","non_theme":true},"personal-computers":{"slug":"personal-computers","kind":"common","non_theme":true}},"title":"Apple Inc. (AAPL) CEO Tim Cook on Q2 2020 Results - Earnings Call Transcript","summary":[],"isPaywalled":false,"lastModified":"2020-05-01T00:48:35-04:00","closestTradingDate":"2020-05-01","isEarningsSlides":false,"isExclusive":false,"isTranscript":true,"excludedByTag":false,"transcriptPath":"https://static.seekingalpha.com/cdn/s3/transcripts_audio/4341792.mp3","likesCount":15,"disabledStatus":"allowed","disabledMessage":null,"status":"published","disclosure":"","articleActionableItem":null,"inEmbargo":false,"isNoindex":false,"isNoarchive":true,"content":"<p>Apple Inc. (<span class=\"ticker-hover-wrapper\">NASDAQ:<a href=\"https://seekingalpha.com/symbol/AAPL\" title=\"Apple Inc.\">AAPL</a></span>) Q2 2020 Results Conference Call April 30, 2020 5:00 PM ET</p> <p><strong>Company Participants</strong></p> <p>Tejas Gala - Senior Manager, Corporate Finance and IR</p> <p>Tim Cook - CEO</p> <p>Luca Maestri - CFO</p> <p><strong>Conference Call Participants</strong></p> <p>Shannon Cross - Cross Research</p> <p>Wamsi Mohan - Bank of America</p> <p>Katy Huberty - Morgan Stanley</p> <p>Amit Daryanani - Evercore</p> <p>Jeriel Ong - Deutsche Bank</p> <p>Samik Chatterjee - JP Morgan</p> <p>Chris Caso - Raymond James</p> <p><strong>Operator</strong></p> <p>Good day everyone. Welcome to the Apple Incorporated Second Quarter Fiscal Year 2020 Earnings Conference Call. Today’s call is being recorded.</p> <p>At this time for opening remarks and introductions, I would like to turn the call over to Mr. Tejas Gala, Senior Manager, Corporate Finance and Investor Relations. Please go ahead.</p> <p><strong>Tejas Gala</strong></p> <p>Thank you. Good afternoon and thank you for joining us.</p> <p>Speaking first today is Apple’s CEO, Tim Cook, and he will be followed by CFO, Luca Maestri. After that, we’ll open the call to questions from analysts.</p> <p>Please note that some of the information you’ll hear during our discussion today will consist of forward-looking statements, including without limitation those regarding revenue, gross margin, operating expenses, other income and expense, taxes, capital allocation and future business outlook including the potential impact of COVID-19 on the Company’s business and results of operations.</p> <p>Actual results or trends could differ materially from our forecast. For more information, please refer to the risk factors discussed in Apple’s most recently filed periodic reports on Form 10-K and Form 10-Q and the Form 8-K filed with the SEC today, along with the associated press release.</p> <p>Apple assumes no obligation to update any forward-looking statements or information, which speaks as of their respective dates.</p> <p>I’d now like to turn the call over to Tim for introductory remarks.</p> <p><strong>Tim Cook</strong></p> <p>Thanks, Tejas. Good afternoon, everyone. Thanks for joining<span class=\"paywall-full-content invisible\"> us today. I hope you’re staying safe and well.</span></p> <p class=\"paywall-full-content invisible\">Today Apple reports $58.3 billion in revenue, an all-time record for Services, and a quarterly record for Wearables, Home and Accessories. It was also a quarterly revenue record for Apple Retail powered by phenomenal grow ...

# %%
pip install finpie
# Out:
# Collecting finpie
#   Downloading finpie-0.1364.tar.gz (40.1 MB)
#      ---------------------------------------- 40.1/40.1 MB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from finpie) (1.4.4)
# Requirement already satisfied: selenium>=3.14.0 in c:\users\user\anaconda3\lib\site-packages (from finpie) (4.7.2)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\user\anaconda3\lib\site-packages (from finpie) (1.21.5)
# Collecting iexfinance
#   Downloading iexfinance-0.5.0-py3-none-any.whl (54 kB)
#      -------------------------------------- 54.3/54.3 kB 312.8 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from finpie) (4.64.1)
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: dask[complete] in c:\users\user\anaconda3\lib\site-packages (from finpie) (2022.7.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from finpie) (4.11.1)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ------------------------------------ 112.2/112.2 kB 407.7 kB/s eta 0:00:00
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from finpie) (4.9.1)
# Requirement already satisfied: xlrd in c:\users\user\anaconda3\lib\site-packages (from finpie) (2.0.1)
# Collecting requests_html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from finpie) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.1->finpie) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.1->finpie) (2022.1)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\user\anaconda3\lib\site-packages (from selenium>=3.14.0->finpie) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\lib\site-packages (from selenium>=3.14.0->finpie) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\user\anaconda3\lib\site-packages (from selenium>=3.14.0->finpie) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\user\anaconda3\lib\site-packages (from selenium>=3.14.0->finpie) (0.9.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp39-cp39-win_amd64.whl (323 kB)
#      ------------------------------------ 323.5/323.5 kB 835.4 kB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->finpie) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (2022.7.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (1.2.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (2.11.3)
# Requirement already satisfied: distributed==2022.7.0 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (2022.7.0)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\user\anaconda3\lib\site-packages (from dask[complete]->finpie) (2.4.3)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (6.1)
# Requirement already satisfied: locket>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (2.1.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (5.9.0)
# Requirement already satisfied: click>=6.6 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (8.0.4)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->finpie) (1.0.3)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from html5lib->finpie) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\anaconda3\lib\site-packages (from html5lib->finpie) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->finpie) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->finpie) (2.0.4)
# Collecting bs4
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: w3lib in c:\users\user\anaconda3\lib\site-packages (from requests_html->finpie) (1.21.0)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyquery
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.1-py3-none-any.whl (50 kB)
#      -------------------------------------- 50.4/50.4 kB 286.6 kB/s eta 0:00:00
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      -------------------------------------- 83.4/83.4 kB 585.1 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->finpie) (0.4.5)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\user\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]->finpie) (4.3.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\user\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]->finpie) (9.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->dask[complete]->finpie) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->dask[complete]->finpie) (3.0.9)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp39-cp39-win_amd64.whl (101 kB)
#      ------------------------------------ 101.4/101.4 kB 729.6 kB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\user\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html->finpie) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\user\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html->finpie) (1.4.4)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: async-generator>=1.9 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (1.10)
# Requirement already satisfied: outcome in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (1.1.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.14.0->finpie) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium>=3.14.0->finpie) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium>=3.14.0->finpie) (1.7.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      -------------------------------------- 56.8/56.8 kB 332.5 kB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting importlib-resources>=5.0
#   Downloading importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Collecting cssselect>=1.2.0
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium>=3.14.0->finpie) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html->finpie) (3.8.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=3.14.0->finpie) (0.14.0)
# Requirement already satisfied: heapdict in c:\users\user\anaconda3\lib\site-packages (from zict>=0.1.3->distributed==2022.7.0->dask[complete]->finpie) (1.0.1)
# Building wheels for collected packages: finpie, bs4, parse
#   Building wheel for finpie (setup.py): started
#   Building wheel for finpie (setup.py): finished with status 'done'
#   Created wheel for finpie: filename=finpie-0.1364-py3-none-any.whl size=40157101 sha256=c0765f1ebb8fe61cd8bdb80c375859c50a2926fa41c4f8cd0737107d665ee15a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\ce\9d\7e\daa56b1f03116dfc2a5c2ee620c067fbf9d29229e40d0bf48c
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=6e33ab3b7fc38e0b08ca00f841f39a1563c8178cbd9dd1b6e6e42cc07f72043a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8b\ac\c5\cb646ab01df6f353a9994b1c97dffb94f9b12013d64c162c58
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24635 sha256=157e6d5d9dfe9482f272b28e9eb8b3e15700d2b5748822b5b3dacb91fa0586eb
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\13\37\a2\e4bbb20a9e1bcb7643e432f71f513ea1fc1fb7f8a1cc718a2f
# Successfully built finpie bs4 parse
# Installing collected packages: pyee, parse, websockets, multidict, importlib-resources, html5lib, frozenlist, cssselect, async-timeout, yarl, pyquery, pyppeteer, fake-useragent, bs4, aiosignal, requests_html, iexfinance, aiohttp, alpha_vantage, finpie
#   Attempting uninstall: cssselect
#     Found existing installation: cssselect 1.1.0
#     Uninstalling cssselect-1.1.0:
#       Successfully uninstalled cssselect-1.1.0
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 alpha_vantage-2.3.1 async-timeout-4.0.2 bs4-0.0.1 cssselect-1.2.0 fake-useragent-1.1.1 finpie-0.1364 frozenlist-1.3.3 html5lib-1.1 iexfinance-0.5.0 importlib-resources-5.10.2 multidict-6.0.4 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests_html-0.10.0 websockets-10.4 yarl-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import finpie # or import finpie.fundamental_data

# default:
# source = 'macrotrends'
# freq = 'A'
fd = finpie.Fundamentals('AAPL', source = 'macrotrends', freq = 'A')

# source options for financial statements and key metrics:
# 'yahoo', 'marketwatch', 'macrotrends'
# freq options:
# 'A', 'Q'

# default key metrics for marketwatch and macrotrends come from Finviz
fd = finpie.Fundamentals('TSLA')
fd.transcripts(html = True)
# Out:
# Failed..

# %%
finpie.__file__
# Out:
# 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\finpie\\__init__.py'

# %%
fd.analyst_ratings()
# Out:
#                 action       rating_institution                rating  \
# date
# 2023-01-27  Reiterated            Deutsche Bank                   Buy
# 2023-01-27  Reiterated        Canaccord Genuity                   Buy
# 2023-01-27   Downgrade        Exane BNP Paribas  Outperform → Neutral
# 2023-01-27  Reiterated                JP Morgan            Overweight
# 2023-01-27  Reiterated              Oppenheimer            Outperform
# 2023-01-27  Reiterated                  Wedbush            Outperform
# 2023-01-27  Reiterated          Robert W. Baird            Outperform
# 2023-01-27  Reiterated  KeyBanc Capital Markets            Overweight
# 2023-01-27  Reiterated            Deutsche Bank                   Buy
# 2023-01-27  Reiterated              DA Davidson                   Buy
# 2023-01-27  Reiterated            Credit Suisse            Outperform
# 2023-01-27  Reiterated                Citigroup                   Buy
# 2023-01-27  Reiterated                 Barclays          Equal Weight
# 2023-01-27  Reiterated           Morgan Stanley            Overweight
# 2023-01-27  Reiterated            Credit Suisse            Outperform
# 2023-01-27  Reiterated                 Barclays          Equal Weight
# 2023-01-27     Upgrade               Rosenblatt         Neutral → Buy
# 2023-01-27   Downgrade          BofA Securities         Buy → Neutral
# 2023-01-27     Upgrade            Credit Suisse  Neutral → Outperform
# 2023-01-27   Initiated                 Itau BBA          Underperform
#
#            price_target
# date
# 2023-01-27  $170 → $160
# 2023-01-27  $200 → $170
# 2023-01-27         $140
# 2023-01-27  $200 → $190
# 2023-01-27  $190 → $170
# 2023-01-27  $220 → $200
# 2023-01-27  $185 → $170
# 2023-01-27  $185 → $177
# 2023-01-27  $175 → $170
# 2023-01-27  $185 → $167
# 2023-01-27  $190 → $184
# 2023-01-27  $185 → $175
# 2023-01-27  $155 → $156
# 2023-01-27  $180 → $177
# 2023-01-27  $201 → $190
# 2023-01-27  $169 → $155
# 2023-01-27  $160 → $189
# 2023-01-27  $185 → $160
# 2023-01-27         $201
# 2023-01-27         $136

# %%
fd = finpie.Fundamentals('AAPL')
fd.transcripts(html = True)
# Out:
# Failed to start driver: Message: session not created: This version of ChromeDriver only supports Chrome version 93
# Current browser version is 109.0.5414.75 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00C3A2D3+2663123]
# 	Ordinal0 [0x00BCA491+2204817]
# 	Ordinal0 [0x00AB2118+1057048]
# 	Ordinal0 [0x00AD041A+1180698]
# 	Ordinal0 [0x00ACC335+1164085]
# 	Ordinal0 [0x00AC9B7F+1153919]
# 	Ordinal0 [0x00AF9D8F+1351055]
# 	Ordinal0 [0x00AF99FA+1350138]
# 	Ordinal0 [0x00AF589B+1333403]
# 	Ordinal0 [0x00AD1F74+1187700]
# 	Ordinal0 [0x00AD2DC9+1191369]
# 	GetHandleVerifier [0x00DD30D6+1610054]
# 	GetHandleVerifier [0x00E7B53B+2299307]
# 	GetHandleVerifier [0x00CC8DA9+519705]
# 	GetHandleVerifier [0x00CC7759+513993]
# 	Ordinal0 [0x00BD112D+2232621]
# 	Ordinal0 [0x00BD55F8+2250232]
# 	Ordinal0 [0x00BD5732+2250546]
# 	Ordinal0 [0x00BDE591+2286993]
# 	BaseThreadInitThunk [0x76E66BD9+25]
# 	RtlGetFullPathName_UEx [0x77918FD2+1218]
# 	RtlGetFullPathName_UEx [0x77918F9D+1165]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19200\442499352.py in <module>
#       1 fd = finpie.Fundamentals('AAPL')
# ----> 2 fd.transcripts(html = True)
#
# ~\anaconda3\lib\site-packages\finpie\fundamental_data\fool.py in transcripts(self, html)
#      47
#      48         url = 'https://www.fool.com/'
# ---> 49         driver = self._load_driver('none')
#      50
#      51         try:
#
# ~\anaconda3\lib\site-packages\finpie\base.py in _load_driver(self, caps, accept_insecure)
#     110                                 print('Try turning off your firewall...')
#     111
# --> 112                 return driver
#     113
#     114         def _get_session(self, url):
#
# UnboundLocalError: local variable 'driver' referenced before assignment
